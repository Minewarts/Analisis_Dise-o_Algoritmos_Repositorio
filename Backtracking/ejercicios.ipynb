# %%
# Paso por referencia - Estudiar | Bracktrack deshace los pasos que uno hizo antes de saltar | Poda, podar ramas que se saben que no van a servir #
# Estudiar debuging

# %%
def formar_s2 (string1:str, string2:str ,)
